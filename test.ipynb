# %%
import pandas as pd
df = pd.read_csv('car-sales.csv')
# print(pd.DataFrame(df))
print(df)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import numpy as np
print("numpy as an arr")
# Out:
# <built-in function array>

# %%
import numpy as np
arr = np.random.rand(300)
print(arr)
# Out:
# [0.95962567 0.57817288 0.07047959 0.99795869 0.19298798 0.90511123
#  0.49885961 0.64950672 0.027732   0.61808335 0.07562672 0.0400809
#  0.85428692 0.33661481 0.28113986 0.73467588 0.28412142 0.63357905
#  0.81753807 0.20208741 0.60543727 0.17391691 0.57143551 0.29467533
#  0.55954335 0.31283943 0.65706437 0.89427755 0.65125276 0.92743901
#  0.52273881 0.97007867 0.22672253 0.32877785 0.14130535 0.78312316
#  0.85313039 0.73846224 0.9511828  0.98335196 0.74901877 0.63928684
#  0.92798057 0.90364122 0.05238602 0.5122364  0.75878774 0.05503365
#  0.16936178 0.68923081 0.64898562 0.41395577 0.83009045 0.76051902
#  0.97143003 0.02385438 0.8748275  0.25831759 0.64558626 0.53386766
#  0.55938238 0.13692524 0.65723289 0.97194183 0.97727021 0.88465377
#  0.11374709 0.09683348 0.36846726 0.28049927 0.33650989 0.89312281
#  0.54578337 0.98266984 0.05314142 0.33034198 0.24551835 0.30475858
#  0.44770552 0.43448404 0.31803335 0.02024249 0.39648041 0.75844366
# ...
